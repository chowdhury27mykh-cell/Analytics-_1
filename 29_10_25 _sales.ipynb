# %% [markdown]
# <a href="https://colab.research.google.com/github/chowdhury27mykh-cell/Analytics-_1/blob/main/29_10_25%20_sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales = pd.read_csv('/content/Sales.csv',parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales.tail(50)
# Out:
#              Date  Day      Month  Year  Customer_Age             Age_Group  \
# 112986 2014-01-24   24    January  2014            44        Adults (35-64)
# 112987 2016-01-24   24    January  2016            44        Adults (35-64)
# 112988 2013-10-25   25    October  2013            44        Adults (35-64)
# 112989 2015-10-25   25    October  2015            44        Adults (35-64)
# 112990 2013-10-28   28    October  2013            29  Young Adults (25-34)
# 112991 2015-10-28   28    October  2015            29  Young Adults (25-34)
# 112992 2013-07-09    9       July  2013            27  Young Adults (25-34)
# 112993 2015-07-09    9       July  2015            27  Young Adults (25-34)
# 112994 2013-10-25   25    October  2013            37        Adults (35-64)
# 112995 2015-10-25   25    October  2015            37        Adults (35-64)
# 112996 2014-03-25   25      March  2014            58        Adults (35-64)
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
sales.describe()
# Out:
#                                 Date            Day           Year  \
# count                         113036  113036.000000  113036.000000
# mean   2014-11-23 12:14:55.063519232      15.665753    2014.401739
# min              2011-01-01 00:00:00       1.000000    2011.000000
# 25%              2013-12-22 00:00:00       8.000000    2013.000000
# 50%              2014-06-27 00:00:00      16.000000    2014.000000
# 75%              2016-01-09 00:00:00      23.000000    2016.000000
# max              2016-07-31 00:00:00      31.000000    2016.000000
# std                              NaN       8.781567       1.272510
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %%
sales.describe(include='all')
# Out:
#                                  Date            Day   Month           Year  \
# count                          113036  113036.000000  113036  113036.000000
# unique                            NaN            NaN      12            NaN
# top                               NaN            NaN    June            NaN
# freq                              NaN            NaN   11234            NaN
# mean    2014-11-23 12:14:55.063519232      15.665753     NaN    2014.401739
# min               2011-01-01 00:00:00       1.000000     NaN    2011.000000
# 25%               2013-12-22 00:00:00       8.000000     NaN    2013.000000
# 50%               2014-06-27 00:00:00      16.000000     NaN    2014.000000
# 75%               2016-01-09 00:00:00      23.000000     NaN    2016.000000
# max               2016-07-31 00:00:00      31.000000     NaN    2016.000000
# std                               NaN       8.781567     NaN       1.272510
#
# ...

# %%
sales.describe(include='object')
# Out:
#          Month       Age_Group Customer_Gender        Country       State  \
# count   113036          113036          113036         113036      113036
# unique      12               4               2              6          53
# top       June  Adults (35-64)               M  United States  California
# freq     11234           55824           58312          39206       22450
#
#        Product_Category     Sub_Category                Product
# count            113036           113036                 113036
# unique                3               17                    130
# top         Accessories  Tires and Tubes  Water Bottle - 30 oz.
# freq              70120            33870                  10794

# %%
sales.shape
# Out:
# (113036, 18)

# %%
sales.isnull().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
sales['Customer_Age'].plot(kind='kde', figsize = (14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
sales['Customer_Age'].plot(kind='box', figsize = (14,6))

# %%
sales.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
sales['Order_Quantity'].mean()
# Out:
# np.float64(11.901659648253654)

# %%
sales.T
# Out:
#                                0                    1       \
# Date              2013-11-26 00:00:00  2015-11-26 00:00:00
# Day                                26                   26
# Month                        November             November
# Year                             2013                 2015
# Customer_Age                       19                   19
# Age_Group                 Youth (<25)          Youth (<25)
# Customer_Gender                     M                    M
# Country                        Canada               Canada
# State                British Columbia     British Columbia
# Product_Category          Accessories          Accessories
# Sub_Category               Bike Racks           Bike Racks
# Product           Hitch Rack - 4-Bike  Hitch Rack - 4-Bike
# Order_Quantity                      8                    8
# Unit_Cost                          45                   45
# Unit_Price                        120                  120
# ...

# %%
sales['Order_Quantity'].plot(kind='hist', bins =30, figsize = (14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='hist', bins =10, figsize = (14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='hist', bins =80, figsize = (14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2016    29398
# 2014    29398
# 2015    24443
# 2013    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %%
sales['Year'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
sales['Year'].value_counts().plot(kind='pie', figsize= (6,4), colors = ['red', 'black', 'blue', 'green', 'yellow', 'purple'])
# Out:
# <Axes: ylabel='count'>

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().head(1)
# Out:
# Country
# United States    39206
# Name: count, dtype: int64

# %%
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
sales['Product'].value_counts(10)
# Out:
# Product
# Water Bottle - 30 oz.      0.095492
# Patch Kit/8 Patches        0.092148
# Mountain Tire Tube         0.060299
# AWC Logo Cap               0.038554
# Sport-100 Helmet, Red      0.037333
#                              ...
# Mountain-100 Silver, 48    0.000513
# Mountain-100 Silver, 42    0.000478
# Mountain-500 Silver, 48    0.000354
# Road-650 Red, 52           0.000283
# Mountain-500 Black, 52     0.000195
# Name: proportion, Length: 130, dtype: float64

# %%
sales['Product'].value_counts().head(10).plot(kind= 'bar', figsize= (14,6))
# Out:
# <Axes: xlabel='Product'>

# %%
sales.plot(kind = 'scatter', x ='Unit_Cost', y = 'Unit_Price', figsize = (6,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>
