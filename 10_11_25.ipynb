# %% [markdown]
# <a href="https://colab.research.google.com/github/chowdhury27mykh-cell/Analytics-_1/blob/main/10_11_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = (input("Enter a word:"))
if word == word[::-1]:
  print("The word is a palindrome" )
else:
  print("The word is a not a palindrome")
# Out:
# Enter a word:mango
# The word is a not a palindrome

# %%
num = int(input("Enter a number:"))
original_num = num
reversed_num = 0
while num>0:
  remainder = num%10
  reversed_num = reversed_num*10 + remainder
  num = num//10
if original_num == reversed_num:
  print("The number is a palindrome")
else:
  print("The number is not a palindrome")
# Out:
# Enter a number:12321
# The number is a palindrome

# %%
num = int(input("Enter a number:"))
if num%2 == 0:
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter a number:951
# The number is odd

# %%
num = int(input("Enter a number:"))
if num<0:
  print("Factorial of negetive number does not exist.")
elif num == 0 or num ==1:
  print("Factorial is 1")
elif num>=2:
  factorial = 1
  for i in range (1,num+1):
    factorial = factorial*i
  print("The factorial of",num,"is",factorial)
# Out:
# Enter a number:-2
# Factorial of negetive number does not exist.

# %%
# Input from user
num = int(input("Enter a number: "))

# Initialize factorial result
factorial = 1

# Calculate factorial using a loop
for i in range(1, num + 1):
    factorial *= i

# Display the result
print(f"The factorial of {num} is {factorial}.")
# Out:
# Enter a number: 0
# The factorial of 0 is 1.

# %%
num = int(input("Enter a number:"))
print("Table of:",num)
for i in range(1,11):
  print(num,"x",i,"=",num*i)
# Out:
# Enter a number:6
# Table of: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %%
def multiplication_table(num):
  for i in range(1,11):
    print(f"{num}x{i} = {num*i}")
multiplication_table(4)
# Out:
# 4x1 = 4
# 4x2 = 8
# 4x3 = 12
# 4x4 = 16
# 4x5 = 20
# 4x6 = 24
# 4x7 = 28
# 4x8 = 32
# 4x9 = 36
# 4x10 = 40

# %%
def factorial(n):
  if n<0:
    return "Factorial for negetive numbers does not exist."
  if n==0 or n==1:
    return 1
  result = 1
  for i in range (2, n+1):
      result *= i
  return result
factorial(4)
# Out:
# 24
